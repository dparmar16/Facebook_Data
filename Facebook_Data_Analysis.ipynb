# %%
import numpy as np
import pandas as pd
import matplotlib
from matplotlib import axes
import matplotlib.pyplot as plt
import sklearn
from sklearn import linear_model
# %matplotlib inline

# %%
df= pd.read_csv("C:\\Users\\dparmar\\Documents\\dataset_Facebook.csv",delimiter=";",encoding="utf-8")

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
#Get number of posts by month
df["Post Month"].value_counts().reset_index().rename(columns={'index':'month'}).sort_values(by='month').plot(kind="line",x='month')

# %%
#Create new column for like percentage of total impressions
df["like_percent"] = df["like"]/df["Lifetime Post Total Reach"]
#Create new column for comment percentage of total impressions
df["comment_percent"] = df["comment"]/df["Lifetime Post Total Reach"]

# %%
x = df["like_percent"]
y = df["comment_percent"]
testplot = plt.subplot(111)
testplot.scatter(df["like_percent"],df["comment_percent"], c=df["Paid"])
plt.xlim(0,0.08)
plt.ylim(0,.01)
plt.title('Comment Percentage vs Like Percentage')
plt.xlabel('Like Percent')
plt.ylabel('Comment Percent')
